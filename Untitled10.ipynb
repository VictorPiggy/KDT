# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LinearRegression
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from sklearn.datasets import load_diabetes

#data = load_diabetes()

#print('>>>X shape {}'.format(data['data'].shape))
#print('>>>Y shape {}'.format(data['target'].shape))
#print(data['DESCR'])

# %%
# 1. 먼저 데이터프레임을 생성합니다.
#df = pd.DataFrame(data['data'], columns=data['feature_names'])

# 2. 생성된 데이터프레임에 describe()를 적용하고 소수점 처리를 합니다.
# applymap은 데이터프레임의 모든 요소에 적용되므로 요약 통계 결과에 적용하기 좋습니다.
#summary = df.describe().applymap(lambda x: f"{x:0.2f}")

# 결과 확인
#print(summary)

#dat2 = pd.read_csv('https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt', sep='\t')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DSNote/fastcampus/refs/heads/main/hotel.csv', sep='\t')
